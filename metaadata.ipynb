# %%
# %sql
-- DESCRIBE HISTORY gold.fact_table;
SELECT current_catalog(), current_schema();
SHOW TABLES IN data_dev_olist.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>gold</td><td>dim_customer</td><td>false</td></tr><tr><td>gold</td><td>dim_date</td><td>false</td></tr><tr><td>gold</td><td>dim_order</td><td>false</td></tr><tr><td>gold</td><td>dim_product</td><td>false</td></tr><tr><td>gold</td><td>dim_review</td><td>false</td></tr><tr><td>gold</td><td>dim_seller</td><td>false</td></tr><tr><td>gold</td><td>fact_table</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM system.information_schema.tables 
WHERE table_catalog = 'data_dev_olist' 
  AND table_schema = 'gold';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql 
DESCRIBE HISTORY data_dev_olist.gold.fact_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql 
DESCRIBE EXTENDED data_dev_olist.gold.fact_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT price FROM data_dev_olist.gold.fact_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
